# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from pandas.plotting import scatter_matrix

# %%
dane = pd.read_csv('C:/Users/Blazej/anaconda3/Python/Projekt ML/heart_failure_clinical_records_dataset.csv')
dane.head()
print(dane["DEATH_EVENT"].value_counts())
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
X = dane.drop(columns="DEATH_EVENT", axis = 1)
y = dane["DEATH_EVENT"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print("ZBIÓR TRENINGOWY:\n",y_train.value_counts())
print("ZBIÓR TESTOWY:\n",y_test.value_counts())
# Out:
# ZBIÓR TRENINGOWY:
#  0    162
# 1     77
# Name: DEATH_EVENT, dtype: int64
# ZBIÓR TESTOWY:
#  0    41
# 1    19
# Name: DEATH_EVENT, dtype: int64

# %%
X_train.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  239.000000  239.000000                239.000000  239.000000
# mean    60.986054    0.426778                591.786611    0.422594
# std     12.142893    0.495648                941.832797    0.495009
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                121.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     69.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7702.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         239.000000           239.000000     239.000000
# mean           38.117155             0.351464  260885.015188
# std            12.278067             0.478430   94408.343494
# min            14.000000             0.000000   47000.000000
# ...

# %%
X_test.describe()
# Out:
#              age    anaemia  creatinine_phosphokinase   diabetes  \
# count  60.000000  60.000000                 60.000000  60.000000
# mean   60.227783   0.450000                542.216667   0.400000
# std    10.925271   0.501692               1083.928372   0.494032
# min    40.000000   0.000000                 47.000000   0.000000
# 25%    50.750000   0.000000                107.750000   0.000000
# 50%    60.000000   0.000000                239.000000   0.000000
# 75%    70.000000   1.000000                582.000000   1.000000
# max    95.000000   1.000000               7861.000000   1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count          60.000000            60.000000      60.000000
# mean           37.950000             0.350000  273208.868667
# std             9.965066             0.480995  110622.787273
# min            20.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  216750.000000
# ...

# %%
X_test.shape
y_test.shape
# Out:
# (60,)

# %%
train_set = pd.DataFrame(X_train)
train_set["DEATH_EVENT"] = y_train
train_set.to_csv("train_set.csv", index=False)
test_set = pd.DataFrame(X_test)
test_set["DEATH_EVENT"] = y_test
test_set.to_csv("test_set.csv", index=False)
